# %%
import pandas as pd

# %%
# dataset
ecom=pd.read_csv("Downloads\ecom - ecom.csv")
ecom
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
# shape of dataset
ecom.shape
# Out:
# (10999, 12)

# %%
# head
ecom.head(5)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
# tail
ecom.tail(5)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 10994             medium      F                 1           1538
# ...

# %%
# displaying feature vecor of row number 180
ecom.iloc[179]
# Out:
# ID                        180
# Warehouse_block             F
# Mode_of_Shipment         Ship
# Customer_care_calls         5
# Customer_rating             5
# Cost_of_the_Product       255
# Prior_purchases             4
# Product_importance     medium
# Gender                      M
# Discount_offered            3
# Weight_in_gms            3440
# Reached.on.Time_Y.N         1
# Name: 179, dtype: object

# %%
ecom.loc[(ecom['Weight_in_gms'] > 7000) & (ecom['Mode_of_Shipment'] == 'Flight')]
# Out:
# Empty DataFrame
# Columns: [ID, Warehouse_block, Mode_of_Shipment, Customer_care_calls, Customer_rating, Cost_of_the_Product, Prior_purchases, Product_importance, Gender, Discount_offered, Weight_in_gms, Reached.on.Time_Y.N]
# Index: []

# %%
# find mean, median and mode of customer_rating
ecom.Customer_rating.mean()
# Out:
# 2.9905445949631786

# %%
ecom.Customer_rating.median()
# Out:
# 3.0

# %%
ecom.Customer_rating.mode()
# Out:
# 0    3
# dtype: int64

# %%
ecom.Customer_rating.var()
# Out:
# 1.9982739259753057

# %%
# descriptive statistics of the numeric features in the dataset
ecom.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...
